# %%
import pandas as pd
import numpy as np
import plotly.express as px

# %%
df=pd.read_csv(r"C:\Users\Masood\Downloads\apps.csv.zip")

# %%
df.head(10)
# Out:
#    Unnamed: 0                                                App  \
# 0           0     Photo Editor & Candy Camera & Grid & ScrapBook
# 1           1                                Coloring book moana
# 2           2  U Launcher Lite – FREE Live Cool Themes, Hide ...
# 3           3                              Sketch - Draw & Paint
# 4           4              Pixel Draw - Number Art Coloring Book
# 5           5                         Paper flowers instructions
# 6           6            Smoke Effect Photo Maker - Smoke Editor
# 7           7                                   Infinite Painter
# 8           8                               Garden Coloring Book
# 9           9                      Kids Paint Free - Drawing Fun
#
#          Category  Rating  Reviews  Size     Installs  Type Price  \
# 0  ART_AND_DESIGN     4.1      159  19.0      10,000+  Free     0
# 1  ART_AND_DESIGN     3.9      967  14.0     500,000+  Free     0
# 2  ART_AND_DESIGN     4.7    87510   8.7   5,000,000+  Free     0
# 3  ART_AND_DESIGN     4.5   215644  25.0  50,000,000+  Free     0
# 4  ART_AND_DESIGN     4.3      967   2.8     100,000+  Free     0
# 5  ART_AND_DESIGN     4.4      167   5.6      50,000+  Free     0
# 6  ART_AND_DESIGN     3.8      178  19.0      50,000+  Free     0
# 7  ART_AND_DESIGN     4.1    36815  29.0   1,000,000+  Free     0
# 8  ART_AND_DESIGN     4.4    13791  33.0   1,000,000+  Free     0
# 9  ART_AND_DESIGN     4.7      121   3.1      10,000+  Free     0
#
#   Content Rating                     Genres        Last Updated  \
# 0       Everyone               Art & Design     January 7, 2018
# 1       Everyone  Art & Design;Pretend Play    January 15, 2018
# 2       Everyone               Art & Design      August 1, 2018
# 3           Teen               Art & Design        June 8, 2018
# 4       Everyone    Art & Design;Creativity       June 20, 2018
# 5       Everyone               Art & Design      March 26, 2017
# 6       Everyone               Art & Design      April 26, 2018
# 7       Everyone               Art & Design       June 14, 2018
# 8       Everyone               Art & Design  September 20, 2017
# 9       Everyone    Art & Design;Creativity        July 3, 2018
#
#           Current Ver   Android Ver
# 0               1.0.0  4.0.3 and up
# 1               2.0.0  4.0.3 and up
# 2               1.2.4  4.0.3 and up
# 3  Varies with device    4.2 and up
# 4                 1.1    4.4 and up
# 5                   1    2.3 and up
# 6                 1.1  4.0.3 and up
# 7            6.1.61.1    4.2 and up
# 8               2.9.2    3.0 and up
# 9                 2.8  4.0.3 and up

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9659 entries, 0 to 9658
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Unnamed: 0      9659 non-null   int64
#  1   App             9659 non-null   object
#  2   Category        9659 non-null   object
#  3   Rating          8196 non-null   float64
#  4   Reviews         9659 non-null   int64
#  5   Size            8432 non-null   float64
#  6   Installs        9659 non-null   object
#  7   Type            9659 non-null   object
#  8   Price           9659 non-null   object
#  9   Content Rating  9659 non-null   object
#  10  Genres          9659 non-null   object
#  11  Last Updated    9659 non-null   object
#  12  Current Ver     9651 non-null   object
#  13  Android Ver     9657 non-null   object
# dtypes: float64(2), int64(2), object(10)
# memory usage: 1.0+ MB

# %%
df.isnull().sum()
# Out:
# Unnamed: 0           0
# App                  0
# Category             0
# Rating            1463
# Reviews              0
# Size              1227
# Installs             0
# Type                 0
# Price                0
# Content Rating       0
# Genres               0
# Last Updated         0
# Current Ver          8
# Android Ver          2
# dtype: int64

# %%
#Handle Missing Values

# %%
initial_rows = len(df)
df.dropna(inplace=True)
rows_after_dropna = len(df)
print(f"Initial rows: {initial_rows}")
print(f"Rows after dropping NaNs: {rows_after_dropna}")
print(f"Rows dropped: {initial_rows - rows_after_dropna}")
print("\n" + "="*50 + "\n")
# Out:
# Initial rows: 9659
# Rows after dropping NaNs: 7021
# Rows dropped: 2638
#
# ==================================================

# %%
#Clean and Convert 'Installs' Column

# %%
df['Installs'] = df['Installs'].str.replace('+', '', regex=False)
df['Installs'] = df['Installs'].str.replace(',', '', regex=False)

# %%
#Convert to integer
df['Installs'] = pd.to_numeric(df['Installs'], errors='coerce').astype(pd.Int64Dtype())
print("Data type for 'Installs' is now:", df['Installs'].dtype)
print("\n" + "="*50 + "\n")
# Out:
# Data type for 'Installs' is now: Int64
#
# ==================================================

# %%
#clean and Convert 'Price' Column

# %%
df['Price'] = df['Price'].str.replace('$', '', regex=False)
# Convert to float
df['Price'] = pd.to_numeric(df['Price'], errors='coerce')
print("Data type for 'Price' is now:", df['Price'].dtype)
print("\n" + "="*50 + "\n")
# Out:
# Data type for 'Price' is now: float64
#
# ==================================================

# %%
print("Final Cleaned DataFrame Info")
df.info()
# Out:
# Final Cleaned DataFrame Info
# <class 'pandas.core.frame.DataFrame'>
# Index: 7021 entries, 0 to 9658
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Unnamed: 0      7021 non-null   int64
#  1   App             7021 non-null   object
#  2   Category        7021 non-null   object
#  3   Rating          7021 non-null   float64
#  4   Reviews         7021 non-null   int64
#  5   Size            7021 non-null   float64
#  6   Installs        7021 non-null   Int64
#  7   Type            7021 non-null   object
#  8   Price           7021 non-null   float64
#  9   Content Rating  7021 non-null   object
#  10  Genres          7021 non-null   object
#  11  Last Updated    7021 non-null   object
#  12  Current Ver     7021 non-null   object
#  13  Android Ver     7021 non-null   object
# dtypes: Int64(1), float64(3), int64(2), object(8)
# memory usage: 829.6+ KB

# %%
df.sample(10)
# Out:
#       Unnamed: 0                             App             Category  Rating  \
# 3534        4436                 Google I/O 2018  BOOKS_AND_REFERENCE     4.3
# 2484        3196     LateRooms: Find Hotel Deals     TRAVEL_AND_LOCAL     4.1
# 347          388             Calls & Text by Mo+        COMMUNICATION     4.2
# 907         1121     Everlance: Free Mileage Log              FINANCE     4.7
# 6751        7810            CamScanner (License)         PRODUCTIVITY     4.4
# 8241        9365            Eh Bee Wallpapers HD      PERSONALIZATION     5.0
# 1797        2295           InfantRisk Center HCP              MEDICAL     2.6
# 4324        5278                  AK Interactive               FAMILY     4.3
# 4511        5475  500 AP World History Questions               FAMILY     4.7
# 8723        9877               EU FTL Calculator             BUSINESS     3.6
#
#       Reviews  Size  Installs  Type  Price Content Rating             Genres  \
# 3534    22401   4.6    500000  Free   0.00       Everyone  Books & Reference
# 2484     2419  13.0   1000000  Free   0.00       Everyone     Travel & Local
# 347     83239  14.0   5000000  Free   0.00       Everyone      Communication
# 907      7514  14.0    100000  Free   0.00       Everyone            Finance
# 6751    26358   0.1    500000  Paid   1.99       Everyone       Productivity
# 8241        4   3.9       100  Free   0.00       Everyone    Personalization
# 1797       41  14.0      1000  Paid   9.99       Everyone            Medical
# 4324      734  13.0     10000  Free   0.00       Everyone      Entertainment
# 4511        7   1.2       100  Paid   9.99       Everyone          Education
# 8723       60   1.8     10000  Free   0.00       Everyone           Business
#
#           Last Updated Current Ver   Android Ver
# 3534       May 7, 2018       6.1.2    5.0 and up
# 2484      May 29, 2018      1.24.5    4.1 and up
# 347     April 19, 2018       3.0.4    4.0 and up
# 907      July 31, 2018   1.9.9.9.3    4.4 and up
# 6751  January 17, 2014         1.7    2.0 and up
# 8241    April 24, 2018           1    4.1 and up
# 1797       May 6, 2015       1.3.4  2.3.3 and up
# 4324     July 12, 2018         2.5    4.0 and up
# 4511  November 1, 2013         1.2    1.6 and up
# 8723      June 1, 2018       1.5.1    4.1 and up

# %%
#A. Correlation Analysis (Rating, Size, Installs, Price)
print("Correlation Matrix (Key Metrics):\n")
numeric_cols = ['Rating', 'Reviews', 'Size', 'Installs', 'Price']
print(df[numeric_cols].corr())

#B. Top 10 Categories by Average Installs (Popularity)
top_categories_installs = df.groupby('Category')['Installs'].mean().sort_values(ascending=False).head(10)
print("\nTop 10 Categories by Average Installs (Popularity):\n", top_categories_installs)

# C. Average Rating by Content Rating
avg_rating_by_content = df.groupby('Content Rating')['Rating'].mean().sort_values(ascending=False)
print("\nAverage Rating by Content Rating:\n", avg_rating_by_content)
# Out:
# Correlation Matrix (Key Metrics):
#
#             Rating   Reviews      Size  Installs     Price
# Rating    1.000000  0.067587  0.062981  0.047600 -0.021158
# Reviews   0.067587  1.000000  0.180484  0.595748 -0.008999
# Size      0.062981  0.180484  1.000000  0.131707 -0.025733
# Installs  0.047600  0.595748  0.131707  1.000000 -0.010567
# Price    -0.021158 -0.008999 -0.025733 -0.010567  1.000000
#
# Top 10 Categories by Average Installs (Popularity):
#  Category
# GAME                  13861000.861779
# ENTERTAINMENT               9968125.0
# COMMUNICATION          9669763.457447
# VIDEO_PLAYERS          7738055.357143
# NEWS_AND_MAGAZINES     7733120.454545
# PHOTOGRAPHY            7323005.539216
# PRODUCTIVITY           5813013.811659
# SHOPPING               4868024.246575
# TOOLS                       4607285.6
# HEALTH_AND_FITNESS     3960503.769634
# Name: Installs, dtype: Float64
#
# Average Rating by Content Rating:
#  Content Rating
# Adults only 18+    4.550000
# Everyone 10+       4.232432
# Teen               4.225546
# Everyone           4.151233
# Mature 17+         4.107895
# Unrated            4.100000
# Name: Rating, dtype: float64

# %%
# 3.Distribution of App Ratings
fig_rating = px.histogram(
    df, 
    x='Rating', 
    title='Distribution of App Ratings',
    marginal='box', # Show box plot for distribution detail (Skill Enhancement: Adding detail)
    color_discrete_sequence=['#FF5733']
)
fig_rating.show()

# %%
#Installs (Popularity) by Category
category_installs = df.groupby('Category')['Installs'].sum().reset_index()

fig_installs = px.bar(
    category_installs.sort_values('Installs', ascending=False), 
    x='Category', 
    y='Installs', 
    title='Total Installs by App Category (Popularity Trend)',
    log_y=True, # Use log scale to show wide install range clearly (Skill Enhancement: Appropriate scaling)
    labels={'Installs': 'Total Installs (Log Scale)'},
    color='Installs',
    color_continuous_scale=px.colors.sequential.Teal
)
fig_installs.update_layout(xaxis={'categoryorder':'total descending'})
fig_installs.show()
#
